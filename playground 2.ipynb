# %%
from IPython.display import Audio

# waveform: torch.Tensor (1D or 2D), sample_rate: int
def play_audio(waveform, sample_rate):
    return Audio(waveform.numpy(), rate=sample_rate)

# %%
import os
import platform
import subprocess

def open_file_with_default_app(file_path):
    system = platform.system()

    if system == 'Darwin':  # macOS
        subprocess.run(['open', file_path])
    elif system == 'Windows':
        os.startfile(file_path)
    elif system == 'Linux':
        subprocess.run(['xdg-open', file_path])
    else:
        raise OSError(f"Unsupported operating system: {system}")

# %% [markdown]
# # VoxPopuli

# %%
import os, glob, random, torchaudio
root_path = "/Volumes/LKieuData/VoxPopuli/unlabelled_data/en/"
paths = glob.glob(os.path.join(root_path, '**', '*.ogg'), recursive=True)

# %%
sampled_file = random.choice(paths)
print("Sampled:", sampled_file)
open_file_with_default_app(sampled_file)
# Out:
# Sampled: /Volumes/LKieuData/VoxPopuli/raw_audios/en/2013/20131125-1600-COMMITTEE-FEMM_en.ogg

# %%
from src.data.vad import find_speech_and_trim, find_overlapped_and_trim
import torchaudio
waveform, sr = torchaudio.load("testVADandLID.m4a")
waveform = find_speech_and_trim(waveform, sr)
play_audio(waveform, sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # AudioSet

# %%
import os
import glob
import random
import torchaudio


root_path = '/Users/lkieu/Desktop/Audioset/processed_no_overlapped_tuned/'
ref = '/Users/lkieu/Desktop/Audioset/audio/bal_train'

paths = glob.glob(os.path.join(root_path, '**', '*.flac'), recursive=True)
sampled_file = random.choice(paths)
ref = os.path.join(ref, sampled_file.split('/')[-1])
print("Sampled:", sampled_file)

# Find the processed version with no lang trim
trimmed_path  = '/Users/lkieu/Desktop/Audioset/processed/'
no_lang_trim = os.path.join(trimmed_path, sampled_file.split('/')[-1])
nlt_wave, nlt_sr = torchaudio.load(no_lang_trim)

pwave, psr = torchaudio.load(sampled_file) # Only lang trim
rwave, rsr = torchaudio.load(ref) # reference

# %%
play_audio(nlt_wave, nlt_sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
play_audio(pwave, psr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
play_audio(rwave, rsr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def resample(waveform, sr, target_sr):
    return torchaudio.transforms.Resample(sr, target_sr)(waveform)

# %%
import torchaudio

# test_flac = '/Users/lkieu/Desktop/Audioset/processed/-5-vmt2iKT0.flac'
test_flac = 'testVADandLID.m4a'
waveform, sr = torchaudio.load(test_flac)
waveform = resample(waveform, sr, 16_000)
# waveform = waveform[:, 16000 * 3:]

# %%
from src.data.lid import infer_lid_distribution, trim_non_target_language

# %%
trimmed, _ = trim_non_target_language(waveform.squeeze(), 16_000, chunk_threshold=0.6)

# %%
play_audio(trimmed, 16_000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
for audio in iter(dataset):
    print(audio)
# Out:
# {'audio': 'a', 'label': 1}
# {'audio': 'b', 'label': 2}
# {'audio': 'c', 'label': 3}

# %%
test_flac = '/Users/lkieu/PycharmProjects/PhonemeAwareFoundational/test_audio/canterburytales_09_chaucer_64kb.flac'
from datasets import Audio, Dataset

# English
dataset = Dataset.from_dict({"audio": [test_flac]})
stream_data = dataset.cast_column("audio", Audio())
en_sample = next(iter(stream_data))["audio"]["array"]
